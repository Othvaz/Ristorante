# %%
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\bombo\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: openpyxl in c:\users\bombo\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\bombo\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bombo\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bombo\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bombo\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: et-xmlfile in c:\users\bombo\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\bombo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import os, glob
import pandas as pd

def parse_recipe_csv(file_path: str):
    with open(file_path, 'r') as f:
        all_lines = f.readlines()

    header_row_index = -1
    for i, line in enumerate(all_lines):
        if line.strip().startswith('ingredients:'):
            header_row_index = i
            break

    if header_row_index == -1:
        raise ValueError("Could not find the 'ingredients:' header row in the file.")

    recipe_row_starting = -1
    for i, line in enumerate(all_lines):
        if line.strip().startswith('cooking instructions:'):
            recipe_row_starting = i
            break
    
    comment_row_index = -1
    for i, line in enumerate(all_lines):
        stripped = line.strip().lower()
        if stripped.startswith('comment:') or stripped.startswith('comments:'):
            comment_row_index = i
            break

    if recipe_row_starting == -1:
        raise ValueError("Could not find the 'cooking instructions:' row in the file.")


    metadata_lines = all_lines[:header_row_index]
    metadata = {}

    target_name_val = None
    english_name_val = None
    
    for line in metadata_lines:
        parts = line.split(',')
        try:
            if 'Unnamed: 5' in line:
                candidate = parts[6].strip()
                if candidate and candidate.lower() != 'unnamed: 6':
                    target_name_val = candidate

            if 'english name:' in line:
                label_index = -1
                for i, part in enumerate(parts):
                    if 'english name:' in part:
                        label_index = i
                        break
                if label_index != -1:
                    for i in range(label_index + 1, len(parts)):
                        candidate = parts[i].strip()
                        if candidate:
                            english_name_val = candidate
                            break
            
            if 'source:' in line:
                metadata['source'] = parts[16].strip()
            if 'region:' in line:
                metadata['region'] = int(parts[16].strip())    
        except (IndexError, ValueError):
            continue
    
    if comment_row_index != -1:
        comment_text = None
        for offset in (1, 2):
            idx = comment_row_index + offset
            if idx >= len(all_lines):
                break
            candidate_line = all_lines[idx].strip()
            if candidate_line:
                comment_text = candidate_line.split(',')[0].strip()
                if comment_text:
                    break

        if comment_text:
            metadata['comments'] = comment_text
            
    metadata['target_name'] = target_name_val if target_name_val else english_name_val
    if not metadata.get('target_name'):
        raise ValueError("File skipped. No name.")
        

    ingredients_df = pd.read_csv(
        file_path,
        header=None,
        skiprows=header_row_index + 1
    )
    # instruction_idx = recipe_row_starting + 1
    # while instruction_idx < len(all_lines):
    #     candidate_line = all_lines[instruction_idx]
    #     if candidate_line.strip() and not all(part.strip() == '' for part in candidate_line.strip().split(',')):
    #         instruction_line = candidate_line
    #         next_idx = instruction_idx + 1
    #         if next_idx < len(all_lines):
    #             next_line = all_lines[next_idx]
    #             if next_line.strip() and not all(part.strip() == '' for part in next_line.strip().split(',')):
    #                 instruction_line = instruction_line.rstrip().rstrip(',') + ' ' + next_line.lstrip().lstrip(',')
    #         break
    #     instruction_idx += 1
    # else:
    #     raise ValueError("can't find non-empty line after 'cooking instructions:'.")

    instruction_idx = recipe_row_starting + 1
    stop_idx = comment_row_index if comment_row_index != -1 else len(all_lines)
    
    instruction_parts = []
    while instruction_idx < stop_idx:
        candidate_line = all_lines[instruction_idx]
        if candidate_line.strip() and not all(part.strip() == '' for part in candidate_line.strip().split(',')):
            cleaned = candidate_line.strip().strip(',')
            if cleaned: instruction_parts.append(cleaned)
        instruction_idx +=1
    
    if not instruction_parts:
        raise ValueError("cant find instruction lines between cooking instructions and comments")

    instruction_line = ' '.join(instruction_parts)

    if not ingredients_df.empty and max([2, 9, 11]) < len(ingredients_df.columns):
        df_useful = ingredients_df[[2, 9, 11]]
        df_useful.columns = ['ingredient', 'quantity', 'unit']
        ingredients_df = df_useful.dropna(subset=['ingredient']).reset_index(drop=True)
        numeric_cols = ['quantity']
        ingredients_df[numeric_cols] = ingredients_df[numeric_cols].apply(pd.to_numeric, errors='coerce')
        ingredients_df['unit'] = ingredients_df['unit'].fillna('item')
    else:
        ingredients_df = pd.DataFrame(columns=['ingredient', 'quantity', 'unit'])

    if not ingredients_df.empty:
        ingredients_df = ingredients_df.groupby('ingredient', as_index=False).agg({
            'quantity': 'sum',
            'unit': 'first'
        })

    try:
        recipe_text = instruction_line.split(',')[0].strip()
    except IndexError:
        recipe_text = "Recipe text not foun in the expected column."

    df_recipe = pd.DataFrame({'recipe': [recipe_text]})

    print("Extracted Data")
    for key, value in metadata.items():
        if key == "target_name":
            print(f"Dish Name: {value}")

    return {
            "file_path": file_path,
            "metadata": metadata,
            "ingredients_df": ingredients_df,
            "instruction_line": instruction_line.strip().rstrip(",")
        }

CSV_DIR = 'files/csvs'
all_csvs = sorted(glob.glob(os.path.join(CSV_DIR, '*.csv')))

parsed_files = []
for fp in all_csvs:
    try:
        parsed_files.append(parse_recipe_csv(fp))
    except Exception as e:
        print(f"Skipping {os.path.basename(fp)} due to error: {e}")

print(f"Ready: parsed {len(parsed_files)} CSV file(s).")
# Out:
# Extracted Data
# Dish Name: Anzac Biscuits
# Extracted Data
# Dish Name: Asparagus Bundles
# Extracted Data
# Dish Name: Baguettes
# Extracted Data
# Dish Name: Baked Mac and Cheese
# Extracted Data
# Dish Name: Baked Walleye
# Extracted Data
# Dish Name: Banana Fritters
# Extracted Data
# Dish Name: Beef Stroganoff
# Extracted Data
# Dish Name: Biscuits and Sausage Gravy
# Extracted Data
# Dish Name: Brian's Marriot Blueberry Muffins
# Extracted Data
# Dish Name: Bolognese Meat Sauce
# Extracted Data
# Dish Name: Breakfast Burrito
# Extracted Data
# Dish Name: Breakfast Scramble with Italian Sausage
# Extracted Data
# Dish Name: British Mushy Peas
# Extracted Data
# Dish Name: Broccoli Bacon Salad
# Skipping Brocolli with Ginger_sheet0.csv due to error: cant find instruction lines between cooking instructions and comments
# Extracted Data
# Dish Name: Brown Sugar Fudge
# Extracted Data
# Dish Name: Buttermilk Biscuits
# Extracted Data
# Dish Name: Caribbean Slaw
# Extracted Data
# Dish Name: Carrot Souffle
# Extracted Data
# Dish Name: Cheese Soup
# Extracted Data
# Dish Name: Chicken Geera
# Extracted Data
# Dish Name: Chicken and Sausage Gumbo
# Extracted Data
# Dish Name: Chili
# Extracted Data
# Dish Name: Cobb Salad
# Extracted Data
# Dish Name: Cracked Wheat Bread
# Extracted Data
# Dish Name: Creamy Tomato Soup
# Extracted Data
# Dish Name: Creole Mustard
# Extracted Data
# Dish Name: Cuban roasted pork
# Extracted Data
# Dish Name: Egg's A'la Caneel
# Extracted Data
# Dish Name: Fish Chowder
# Extracted Data
# Dish Name: Fried Chicken
# Extracted Data
# Dish Name: Fry Bread
# Extracted Data
# Dish Name: Fudgy Brownies
# Extracted Data
# Dish Name: Garlic Mash
# Extracted Data
# Dish Name: General Tso's Chicken
# Extracted Data
# Dish Name: Ginger Seasame Salmon
# Extracted Data
# Dish Name: Grandma's Fancy Meat Loaf
# Extracted Data
# Dish Name: Green Bean Casserole
# Extracted Data
# Dish Name: Hard Rolls
# Extracted Data
# Dish Name: Harvest Quiche
# Extracted Data
# Dish Name: Hawaiian Pork Kabobs
# Extracted Data
# Dish Name: Hush puppies
# Extracted Data
# Dish Name: Irish Stew
# Extracted Data
# Dish Name: Jambalaya - hometown
# Extracted Data
# Dish Name: Jerk Chicken
# Extracted Data
# Dish Name: Kansas City Style BBQ Ribs
# Extracted Data
# Dish Name: Loaded Potato Soup
# Extracted Data
# Dish Name: Lobster Rolls
# Extracted Data
# Dish Name: Mango dipping Sauce
# Extracted Data
# Dish Name: Maple Glazed Salmon
# Extracted Data
# Dish Name: 17th de Mai Kringle
# Extracted Data
# Dish Name: Mushroom Avocado Salad
# Extracted Data
# Dish Name: Mustard-dill Sauce
# Skipping Nigerian Chicken_sheet0.csv due to error: cant find instruction lines between cooking instructions and comments
# Extracted Data
# Dish Name: Omelet bake
# Extracted Data
# Dish Name: Pear/Gruyere French Toast
# Extracted Data
# Dish Name: Pineapple Bars
# Extracted Data
# Dish Name: Piri Piri Shrimp
# Extracted Data
# Dish Name: Plain White Bread
# Extracted Data
# Dish Name: Poor Boy - Beef
# Extracted Data
# Dish Name: porridge
# Extracted Data
# Dish Name: Pot Roast
# Extracted Data
# Dish Name: Pulled Pork
# Extracted Data
# Dish Name: Pumpkin Fritters
# Extracted Data
# Dish Name: Reggae Rice
# Extracted Data
# Dish Name: Rhubarb Custard Pie
# Extracted Data
# Dish Name: Sausage gravy
# Extracted Data
# Dish Name: Sausage Rolls
# Extracted Data
# Dish Name: Seasoned Breakfast Potatoes
# Extracted Data
# Dish Name: Sheppard's Pie
# Extracted Data
# Dish Name: Shrimp Scampi
# Extracted Data
# Dish Name: Cole Slaw
# Extracted Data
# Dish Name: Snickerdoodles
# Extracted Data
# Dish Name: Rice Spam and Eggs
# Extracted Data
# Dish Name: Split Pea Dhal
# Extracted Data
# Dish Name: Steam Buns
# Extracted Data
# Dish Name: Stewed Beef and Dumplings
# Extracted Data
# Dish Name: Stuffed Peppers
# Extracted Data
# Dish Name: Herb & Wild rice stuffing
# Extracted Data
# Dish Name: Hawaiian Sweet Bread
# Extracted Data
# Dish Name: Hawaiian Sweet Bread
# Extracted Data
# Dish Name: Sweet Potato Pancakes
# Extracted Data
# Dish Name: Sweet & Sour Squash Soup
# Extracted Data
# Dish Name: Taco Meat
# Extracted Data
# Dish Name: Tator Tot hotdish
# Skipping Thai Vegetable Curry_sheet0.csv due to error: File skipped. No name.
# Extracted Data
# Dish Name: Three Sisters Soup
# Extracted Data
# Dish Name: Breaded Tilapia with macadamia
# Extracted Data
# Dish Name: Tomato Sage Soup
# Extracted Data
# Dish Name: Tuna Salad
# Extracted Data
# Dish Name: Tuscan Bread
# Extracted Data
# Dish Name: Tzaziki Sauce
# Skipping Udo's Vegan Curry_sheet0.csv due to error: cant find instruction lines between cooking instructions and comments
# Extracted Data
# Dish Name: Summer Vegetable Pasta Salad
# Extracted Data
# Dish Name: Veggie Dip
# Extracted Data
# Dish Name: Venison Stew
# Extracted Data
# Dish Name: Wild Rice Hot Dish
# Extracted Data
# Dish Name: Wild Rice Salad
# Extracted Data
# Dish Name: Wild Rice Soup with Bacon
# Extracted Data
# Dish Name: cranberry sauce
# Extracted Data
# Dish Name: Creamed Corn
# Extracted Data
# Dish Name: French Toast
# Ready: parsed 98 CSV file(s).

# %%
import psycopg2
import pandas as pd

db_params = {
    'dbname': 'ristorante',
    'user': 'headchef',
    'password': '123',
    'host': '127.0.0.1',
    'port': '5432'
}

def get_or_create_id(cur, table, id_col, name_col, name_value):
    cur.execute(f"SELECT {id_col} FROM {table} WHERE {name_col} = %s", (name_value,))
    result = cur.fetchone()

    if result:
        return result[0]
    else:
        print(f"'{name_value}' not found in '{table}'. Creating new entry...")
        cur.execute(f"INSERT INTO {table} ({name_col}) VALUES (%s) RETURNING {id_col}", (name_value,))
        new_id = cur.fetchone()[0]
        return new_id


# recipe_name = metadata.get('target_name', 'Unnamed Recipe')
# instructions = ' '.join(instruction_line.strip().rstrip(',').split())

print("Connecting to the database...")
conn = psycopg2.connect(**db_params)

try:
    with conn.cursor() as cur:
        for item in parsed_files:
            metadata = item["metadata"]
            recipe_name = metadata.get("target_name", "Unnamed Recipe")
            instructions = ' '.join(item["instruction_line"].split())
            comments = metadata.get("comments")
            ingredients_df = item["ingredients_df"]

            cur.execute(
                "SELECT EXISTS(SELECT 1 FROM recipes WHERE recipe_name = %s)",
                (recipe_name,)
            )
            if cur.fetchone()[0]:
                print(f"'{recipe_name}' exists already. Skipping.")
                continue

            cur.execute(
                "INSERT INTO recipes (recipe_name, instructions, comments) VALUES (%s, %s, %s) RETURNING recipe_id;",
                (recipe_name, instructions, comments)
            )
            new_recipe_id = cur.fetchone()[0]

            if not ingredients_df.empty:
                for _, row in ingredients_df.iterrows():
                    ingredient_id = get_or_create_id(cur, 'ingredients', 'ingredient_id', 'ingredient_name', row['ingredient'])
                    unit_id = get_or_create_id(cur, 'units', 'unit_id', 'unit_name', row['unit'])
                    cur.execute(
                        "INSERT INTO recipe_ingredients (recipe_id, ingredient_id, quantity, unit_id) VALUES (%s, %s, %s, %s);",
                        (new_recipe_id, ingredient_id, row['quantity'], unit_id)
                    )

            print(f"Inserted '{recipe_name}' (ID {new_recipe_id}) with {0 if ingredients_df.empty else len(ingredients_df)} ingredient rows.")

        conn.commit()
        print("Transaction successful!")

except (Exception, psycopg2.DatabaseError) as error:
    print(f"An error occurred: {error}")
    conn.rollback()
finally:
    conn.close()
    print("Database connection closed.")
# Out:
# Connecting to the database...
# ' can sub Light corn if cane ot available.' not found in 'ingredients'. Creating new entry...
# 'item' not found in 'units'. Creating new entry...
# 'AP flour' not found in 'ingredients'. Creating new entry...
# 'Chicken Thighs' not found in 'ingredients'. Creating new entry...
# 'Chive' not found in 'ingredients'. Creating new entry...
# 'Cilantro sm bunch' not found in 'ingredients'. Creating new entry...
# 'Cumin' not found in 'ingredients'. Creating new entry...
# 'Curry Powder' not found in 'ingredients'. Creating new entry...
# 'Garlic Chopped' not found in 'ingredients'. Creating new entry...
# 'Pepper (jal or pob)' not found in 'ingredients'. Creating new entry...
# 'Pimento' not found in 'ingredients'. Creating new entry...
# 'Thyme Fresh' not found in 'ingredients'. Creating new entry...
# 'onion' not found in 'ingredients'. Creating new entry...
# Inserted 'Chicken Geera' (ID 20) with 11 ingredient rows.
# 'Bay Leaves' not found in 'ingredients'. Creating new entry...
# 'Celery' not found in 'ingredients'. Creating new entry...
# 'Chicken Stock' not found in 'ingredients'. Creating new entry...
# 'Creole Seasoning' not found in 'ingredients'. Creating new entry...
# 'File Powder -sub corn starch if we don't have' not found in 'ingredients'. Creating new entry...
# 'Green Onion' not found in 'ingredients'. Creating new entry...
# 'Grn Peppers' not found in 'ingredients'. Creating new entry...
# 'Onion' not found in 'ingredients'. Creating new entry...
# 'Parsley -chopped' not found in 'ingredients'. Creating new entry...
# 'Smoked Sausage' not found in 'ingredients'. Creating new entry...
# 'Veg oil' not found in 'ingredients'. Creating new entry...
# Inserted 'Chicken and Sausage Gumbo' (ID 21) with 15 ingredient rows.
# 'Garlic -clove/minced' not found in 'ingredients'. Creating new entry...
# 'Grd beef' not found in 'ingredients'. Creating new entry...
# 'Grd cumin' not found in 'ingredients'. Creating new entry...
# 'Sweet paprika ' not found in 'ingredients'. Creating new entry...
# 'Water' not found in 'ingredients'. Creating new entry...
# 'bay leaves' not found in 'ingredients'. Creating new entry...
# 'cayenne pepper' not found in 'ingredients'. Creating new entry...
# 'chili powder' not found in 'ingredients'. Creating new entry...
# 'cornmeal' not found in 'ingredients'. Creating new entry...
# Inserted 'Chili' (ID 22) with 16 ingredient rows.
# 'Avocado' not found in 'ingredients'. Creating new entry...
# 'Bacon' not found in 'ingredients'. Creating new entry...
# 'slice' not found in 'units'. Creating new entry...
# 'Blue Cheese Crumble' not found in 'ingredients'. Creating new entry...
# 'Chicken' not found in 'ingredients'. Creating new entry...
# 'Ranch Dressing' not found in 'ingredients'. Creating new entry...
# 'lettuce' not found in 'ingredients'. Creating new entry...
# Inserted 'Cobb Salad' (ID 23) with 9 ingredient rows.
# Inserted 'Cracked Wheat Bread' (ID 24) with 0 ingredient rows.
# 'Chicken Stock base' not found in 'ingredients'. Creating new entry...
# 'Cream' not found in 'ingredients'. Creating new entry...
# 'Garlic Clove, sliced' not found in 'ingredients'. Creating new entry...
# 'Onion, medium' not found in 'ingredients'. Creating new entry...
# 'Tomatoes, large, peeled and cubed' not found in 'ingredients'. Creating new entry...
# Inserted 'Creamy Tomato Soup' (ID 25) with 9 ingredient rows.
# 'Dijon mustard' not found in 'ingredients'. Creating new entry...
# 'Worcestershire Sauce' not found in 'ingredients'. Creating new entry...
# 'hot Sauce (too taste)' not found in 'ingredients'. Creating new entry...
# Inserted 'Creole Mustard' (ID 26) with 3 ingredient rows.
# 'Bay leaves' not found in 'ingredients'. Creating new entry...
# 'black pepper ' not found in 'ingredients'. Creating new entry...
# 'tsp.' not found in 'units'. Creating new entry...
# 'dried oregano ' not found in 'ingredients'. Creating new entry...
# 'garlic cloves, crushed' not found in 'ingredients'. Creating new entry...
# 'ct.' not found in 'units'. Creating new entry...
# 'oil' not found in 'ingredients'. Creating new entry...
# 'C.' not found in 'units'. Creating new entry...
# 'onion, sliced ' not found in 'ingredients'. Creating new entry...
# 'pork loin or pork shoulder' not found in 'ingredients'. Creating new entry...
# 'lbs.' not found in 'units'. Creating new entry...
# 'sour orange juice, (2/3 fresh oj & 1/3 lemon j)' not found in 'ingredients'. Creating new entry...
# 'gal.' not found in 'units'. Creating new entry...
# Inserted 'Cuban roasted pork' (ID 27) with 9 ingredient rows.
# 'Hollandaise Sauce:' not found in 'ingredients'. Creating new entry...
# 'Tomatoes -hollowed into cups' not found in 'ingredients'. Creating new entry...
# 'butter - quartered' not found in 'ingredients'. Creating new entry...
# 'egg yolk' not found in 'ingredients'. Creating new entry...
# 'eggs (pasteurized ???) ' not found in 'ingredients'. Creating new entry...
# 'grd pork-chopped' not found in 'ingredients'. Creating new entry...
# 'lemon juice' not found in 'ingredients'. Creating new entry...
# 'onion -chopped' not found in 'ingredients'. Creating new entry...
# Inserted 'Egg's A'la Caneel' (ID 28) with 9 ingredient rows.
# 'Allspice' not found in 'ingredients'. Creating new entry...
# 'Cod' not found in 'ingredients'. Creating new entry...
# 'Dillweed' not found in 'ingredients'. Creating new entry...
# 'Evaporated Milk' not found in 'ingredients'. Creating new entry...
# 'Medium Onion' not found in 'ingredients'. Creating new entry...
# 'Medium Potato' not found in 'ingredients'. Creating new entry...
# Inserted 'Fish Chowder' (ID 29) with 10 ingredient rows.
# 'Beer' not found in 'ingredients'. Creating new entry...
# 'Tsp' not found in 'units'. Creating new entry...
# 'Egg' not found in 'ingredients'. Creating new entry...
# 'Fryer Chicken, cut up' not found in 'ingredients'. Creating new entry...
# 'Parsley' not found in 'ingredients'. Creating new entry...
# 'Vegetable Oil for Frying' not found in 'ingredients'. Creating new entry...
# Inserted 'Fried Chicken' (ID 30) with 9 ingredient rows.
# 'enriched AP flour' not found in 'ingredients'. Creating new entry...
# 'gal' not found in 'units'. Creating new entry...
# Inserted 'Fry Bread' (ID 31) with 4 ingredient rows.
# Inserted 'Fudgy Brownies' (ID 32) with 0 ingredient rows.
# 'Garlic cloves' not found in 'ingredients'. Creating new entry...
# 'Russet Potatoes' not found in 'ingredients'. Creating new entry...
# 'Salt and pepper to taste' not found in 'ingredients'. Creating new entry...
# 'olive Oil' not found in 'ingredients'. Creating new entry...
# Inserted 'Garlic Mash' (ID 33) with 6 ingredient rows.
# 'Batter:' not found in 'ingredients'. Creating new entry...
# 'Sauce:' not found in 'ingredients'. Creating new entry...
# 'T.' not found in 'units'. Creating new entry...
# 'chicken thighs' not found in 'ingredients'. Creating new entry...
# 'cornstarch +2tsp.' not found in 'ingredients'. Creating new entry...
# 'dried pepper pods' not found in 'ingredients'. Creating new entry...
# 'eggs, beaten' not found in 'ingredients'. Creating new entry...
# Inserted 'Lobster Rolls' (ID 47) with 11 ingredient rows.
# 'Grn bell pepper  -small dice' not found in 'ingredients'. Creating new entry...
# 'Red bell pepper  -small dice' not found in 'ingredients'. Creating new entry...
# 'Red wine Vinegar' not found in 'ingredients'. Creating new entry...
# 'mango -pureed' not found in 'ingredients'. Creating new entry...
# Inserted 'Mango dipping Sauce' (ID 48) with 6 ingredient rows.
# 'Maple Syrup' not found in 'ingredients'. Creating new entry...
# 'Maple Syrup (again)' not found in 'ingredients'. Creating new entry...
# 'Salmon Fillets - 8 oz' not found in 'ingredients'. Creating new entry...
# Inserted 'Maple Glazed Salmon' (ID 49) with 4 ingredient rows.
# 'Fillings :' not found in 'ingredients'. Creating new entry...
# 'almonds (ground)' not found in 'ingredients'. Creating new entry...
# 'raisins' not found in 'ingredients'. Creating new entry...
# Inserted '17th de Mai Kringle' (ID 50) with 9 ingredient rows.
# 'Avocado -peeled/sliced' not found in 'ingredients'. Creating new entry...
# 'Garlic clove -crushed' not found in 'ingredients'. Creating new entry...
# 'Lime juice' not found in 'ingredients'. Creating new entry...
# 'Lime zest' not found in 'ingredients'. Creating new entry...
# 'Mushrooms -quartered' not found in 'ingredients'. Creating new entry...
# 'Olive oil' not found in 'ingredients'. Creating new entry...
# 'Red onion' not found in 'ingredients'. Creating new entry...
# 'Small Red Chili -seeded and minced' not found in 'ingredients'. Creating new entry...
# 'Spring mix' not found in 'ingredients'. Creating new entry...
# 'Sundried Tomatoes' not found in 'ingredients'. Creating new entry...
# Inserted 'Mushroom Avocado Salad' (ID 51) with 11 ingredient rows.
# 'Fresh dill -chopped' not found in 'ingredients'. Creating new entry...
# 'Kosher salt -to taste' not found in 'ingredients'. Creating new entry...
# 'Lemon juice' not found in 'ingredients'. Creating new entry...
# 'Mayo' not found in 'ingredients'. Creating new entry...
# 'Mustard Powder' not found in 'ingredients'. Creating new entry...
# 'Pepper -to taste' not found in 'ingredients'. Creating new entry...
# 'Whole grain mustard' not found in 'ingredients'. Creating new entry...
# Inserted 'Mustard-dill Sauce' (ID 52) with 9 ingredient rows.
# '1/2 & 1/2' not found in 'ingredients'. Creating new entry...
# 'Cheddar cheese -shredded' not found in 'ingredients'. Creating new entry...
# 'Ham -cooked and  finely chopped' not found in 'ingredients'. Creating new entry...
# 'green pepper -finely chopped' not found in 'ingredients'. Creating new entry...
# Inserted 'Omelet bake' (ID 53) with 6 ingredient rows.
# 'French/Italian bread -cubed' not found in 'ingredients'. Creating new entry...
# 'Gruyere -shredded' not found in 'ingredients'. Creating new entry...
# 'cinnamon' not found in 'ingredients'. Creating new entry...
# 'pears' not found in 'ingredients'. Creating new entry...
# 'vanilla' not found in 'ingredients'. Creating new entry...
# Inserted 'Pear/Gruyere French Toast' (ID 54) with 10 ingredient rows.
# 'Coconut Flake' not found in 'ingredients'. Creating new entry...
# 'Topping' not found in 'ingredients'. Creating new entry...
# 'pineapple' not found in 'ingredients'. Creating new entry...
# Inserted 'Pineapple Bars' (ID 55) with 9 ingredient rows.
# 'Dried habanero -seeded and chopped' not found in 'ingredients'. Creating new entry...
# 'Garlic -crushed' not found in 'ingredients'. Creating new entry...
# 'Kosher salt' not found in 'ingredients'. Creating new entry...
# 'Medium Shrimp' not found in 'ingredients'. Creating new entry...
# 'crushed ginger' not found in 'ingredients'. Creating new entry...
# Inserted 'Piri Piri Shrimp' (ID 56) with 9 ingredient rows.
# Inserted 'Plain White Bread' (ID 57) with 0 ingredient rows.
# 'Beef (chuck,round, etc…)' not found in 'ingredients'. Creating new entry...
# 'Beef broth' not found in 'ingredients'. Creating new entry...
# 'Creole Mustard' not found in 'ingredients'. Creating new entry...
# 'Garlic Powder' not found in 'ingredients'. Creating new entry...
# 'Kitchen Bouquet' not found in 'ingredients'. Creating new entry...
# 'Shredded Lettuce' not found in 'ingredients'. Creating new entry...
# 'Sliced Tomatoes' not found in 'ingredients'. Creating new entry...
# 'Vegatable Oil' not found in 'ingredients'. Creating new entry...
# Inserted 'Poor Boy - Beef' (ID 58) with 12 ingredient rows.
# 'bananas  -sliced' not found in 'ingredients'. Creating new entry...
# Inserted 'porridge' (ID 59) with 6 ingredient rows.
# 'Baby Carrots' not found in 'ingredients'. Creating new entry...
# 'Beef Broth' not found in 'ingredients'. Creating new entry...
# 'Butter or Oil' not found in 'ingredients'. Creating new entry...
# 'Eye of Round' not found in 'ingredients'. Creating new entry...
# 'Onion - Sliced Thick' not found in 'ingredients'. Creating new entry...
# 'Parsnip' not found in 'ingredients'. Creating new entry...
# 'Red Wine' not found in 'ingredients'. Creating new entry...
# 'Rosemary Sprigs' not found in 'ingredients'. Creating new entry...
# 'Rutabaga' not found in 'ingredients'. Creating new entry...
# 'Thyme Sprigs' not found in 'ingredients'. Creating new entry...
# 'Turnips' not found in 'ingredients'. Creating new entry...
# Inserted 'Pot Roast' (ID 60) with 12 ingredient rows.
# 'Blk Pepper' not found in 'ingredients'. Creating new entry...
# 'Brown sugar' not found in 'ingredients'. Creating new entry...
# 'Cider Vinegar' not found in 'ingredients'. Creating new entry...
# 'Pork shoulder' not found in 'ingredients'. Creating new entry...
# 'garlic cloves -minced' not found in 'ingredients'. Creating new entry...
# Inserted 'Pulled Pork' (ID 61) with 8 ingredient rows.
# 'Pumpkin -solid pack' not found in 'ingredients'. Creating new entry...
# 'baking soda' not found in 'ingredients'. Creating new entry...
# 'buttermilk' not found in 'ingredients'. Creating new entry...
# Inserted 'Pumpkin Fritters' (ID 62) with 8 ingredient rows.
# 'Veg. Oil' not found in 'ingredients'. Creating new entry...
# 'carrot -grated' not found in 'ingredients'. Creating new entry...
# 'garlic -minced' not found in 'ingredients'. Creating new entry...
# 'green pepper -chopped' not found in 'ingredients'. Creating new entry...
# 'rice' not found in 'ingredients'. Creating new entry...
# 'white pepper' not found in 'ingredients'. Creating new entry...
# Inserted 'Reggae Rice' (ID 63) with 9 ingredient rows.
# Inserted 'Rhubarb Custard Pie' (ID 64) with 0 ingredient rows.
# 'Dry sage' not found in 'ingredients'. Creating new entry...
# 'Ground Pork' not found in 'ingredients'. Creating new entry...
# 'Marjoram' not found in 'ingredients'. Creating new entry...
# 'Red pepper flake' not found in 'ingredients'. Creating new entry...
# 'gravy:' not found in 'ingredients'. Creating new entry...
# 'ground clove' not found in 'ingredients'. Creating new entry...
# Inserted 'Sausage gravy' (ID 65) with 12 ingredient rows.
# 'Basil' not found in 'ingredients'. Creating new entry...
# 'Chives -minced' not found in 'ingredients'. Creating new entry...
# 'Garlic cloves -minced' not found in 'ingredients'. Creating new entry...
# 'Pork sausage (bulk)' not found in 'ingredients'. Creating new entry...
# 'Puff pastry' not found in 'ingredients'. Creating new entry...
# 'salt ' not found in 'ingredients'. Creating new entry...
# Inserted 'Sausage Rolls' (ID 66) with 9 ingredient rows.
# 'B-red Potatoes -quartered (skin on)' not found in 'ingredients'. Creating new entry...
# 'seasoning salt' not found in 'ingredients'. Creating new entry...
# 'qrt' not found in 'units'. Creating new entry...
# Inserted 'Seasoned Breakfast Potatoes' (ID 67) with 7 ingredient rows.
# 'Ap flour' not found in 'ingredients'. Creating new entry...
# 'C' not found in 'units'. Creating new entry...
# 'Butter -softened' not found in 'ingredients'. Creating new entry...
# 'Fresh parsley -chopped' not found in 'ingredients'. Creating new entry...
# 'Ground beef' not found in 'ingredients'. Creating new entry...
# 'Italian seasoning' not found in 'ingredients'. Creating new entry...
# 'Pototoes -peeled/diced' not found in 'ingredients'. Creating new entry...
# 'carrots -diced' not found in 'ingredients'. Creating new entry...
# 'salt/pepper to taste' not found in 'ingredients'. Creating new entry...
# Inserted 'Sheppard's Pie' (ID 68) with 16 ingredient rows.
# 'Basil -fresh' not found in 'ingredients'. Creating new entry...
# 'Garlic -finely chopped' not found in 'ingredients'. Creating new entry...
# 'Green Onion -thinnly sliced' not found in 'ingredients'. Creating new entry...
# 'Shrimp' not found in 'ingredients'. Creating new entry...
# Inserted 'Shrimp Scampi' (ID 69) with 8 ingredient rows.
# 'Cabbage' not found in 'ingredients'. Creating new entry...
# Inserted 'Cole Slaw' (ID 70) with 5 ingredient rows.
# Inserted 'Snickerdoodles' (ID 71) with 0 ingredient rows.
# 'Cooked Rice' not found in 'ingredients'. Creating new entry...
# 'Rice Vinegar' not found in 'ingredients'. Creating new entry...
# 'Salt and Pepper' not found in 'ingredients'. Creating new entry...
# 'Spam -cubed' not found in 'ingredients'. Creating new entry...
# 'can' not found in 'units'. Creating new entry...
# Inserted 'Rice Spam and Eggs' (ID 72) with 8 ingredient rows.
# ' Dried Split Peas' not found in 'ingredients'. Creating new entry...
# 'Clove' not found in 'ingredients'. Creating new entry...
# 'Onion -Diced' not found in 'ingredients'. Creating new entry...
# 'Tumeric' not found in 'ingredients'. Creating new entry...
# 'Veggie Broth' not found in 'ingredients'. Creating new entry...
# Inserted 'Split Pea Dhal' (ID 73) with 10 ingredient rows.
# Inserted 'Steam Buns' (ID 74) with 0 ingredient rows.
# 'Ball Tip Cubed' not found in 'ingredients'. Creating new entry...
# 'Chives' not found in 'ingredients'. Creating new entry...
# 'Coconut Milk' not found in 'ingredients'. Creating new entry...
# 'Dumplings:' not found in 'ingredients'. Creating new entry...
# 'Garlic Cloves -chopped' not found in 'ingredients'. Creating new entry...
# 'Oil' not found in 'ingredients'. Creating new entry...
# 'Thyme' not found in 'ingredients'. Creating new entry...
# 'salt  -to taste' not found in 'ingredients'. Creating new entry...
# Inserted 'Stewed Beef and Dumplings' (ID 75) with 15 ingredient rows.
# 'Basil, Parsley, Dill, Salt & Pepper' not found in 'ingredients'. Creating new entry...
# 'Butter or Oil ' not found in 'ingredients'. Creating new entry...
# 'Cheddar Cheese,   as a melted garnish ' not found in 'ingredients'. Creating new entry...
# 'Diced Tomatoes, pureed' not found in 'ingredients'. Creating new entry...
# 'Feta Cheese' not found in 'ingredients'. Creating new entry...
# 'Finely Minced Onion' not found in 'ingredients'. Creating new entry...
# 'Garlic' not found in 'ingredients'. Creating new entry...
# 'Green Pepper    ' not found in 'ingredients'. Creating new entry...
# 'Ground Pork ' not found in 'ingredients'. Creating new entry...
# 'Olive Oil to drizzle of top of Peppers ' not found in 'ingredients'. Creating new entry...
# 'Rice (or Barley or Buckwheat Grouts) ' not found in 'ingredients'. Creating new entry...
# 'Shredded Carrots ' not found in 'ingredients'. Creating new entry...
# 'Shredded Mushrooms' not found in 'ingredients'. Creating new entry...
# 'Tomato Sauce' not found in 'ingredients'. Creating new entry...
# Inserted 'Stuffed Peppers' (ID 76) with 15 ingredient rows.
# 'Chicken stock' not found in 'ingredients'. Creating new entry...
# 'Wild rice' not found in 'ingredients'. Creating new entry...
# 'bread cubes  dry/stale' not found in 'ingredients'. Creating new entry...
# 'celery  -chopped' not found in 'ingredients'. Creating new entry...
# 'dried parsley' not found in 'ingredients'. Creating new entry...
# 'garlic clove -minced' not found in 'ingredients'. Creating new entry...
# 'onion  -chopped' not found in 'ingredients'. Creating new entry...
# 'rosemary' not found in 'ingredients'. Creating new entry...
# 'sage' not found in 'ingredients'. Creating new entry...
# 'thyme' not found in 'ingredients'. Creating new entry...
# Inserted 'Herb & Wild rice stuffing' (ID 77) with 13 ingredient rows.
# Inserted 'Hawaiian Sweet Bread' (ID 78) with 0 ingredient rows.
# 'Hawaiian Sweet Bread' exists already. Skipping.
# 'Sweet potatoes -canned' not found in 'ingredients'. Creating new entry...
# 'nutmeg' not found in 'ingredients'. Creating new entry...
# Inserted 'Sweet Potato Pancakes' (ID 79) with 8 ingredient rows.
# 'Apricot Preserves' not found in 'ingredients'. Creating new entry...
# 'Coriander' not found in 'ingredients'. Creating new entry...
# 'Garlic - minced' not found in 'ingredients'. Creating new entry...
# 'Ginger - minced' not found in 'ingredients'. Creating new entry...
# 'Jalepeno - seeded and minced' not found in 'ingredients'. Creating new entry...
# 'Onion - diced' not found in 'ingredients'. Creating new entry...
# 'Red Potato - peeled and diced' not found in 'ingredients'. Creating new entry...
# 'Squash - peeled and cubed' not found in 'ingredients'. Creating new entry...
# 'Vegetable Stock' not found in 'ingredients'. Creating new entry...
# Inserted 'Sweet & Sour Squash Soup' (ID 80) with 12 ingredient rows.
# 'Cup' not found in 'units'. Creating new entry...
# 'Chicken Breast shredded/diced' not found in 'ingredients'. Creating new entry...
# 'Garlic powder' not found in 'ingredients'. Creating new entry...
# 'Onion powder' not found in 'ingredients'. Creating new entry...
# 'Onions, minced' not found in 'ingredients'. Creating new entry...
# 'Paprika' not found in 'ingredients'. Creating new entry...
# Inserted 'Taco Meat' (ID 81) with 9 ingredient rows.
# 'Cream of celery soup' not found in 'ingredients'. Creating new entry...
# 'Cream of mushroom soup' not found in 'ingredients'. Creating new entry...
# 'Green Beans (french cut)' not found in 'ingredients'. Creating new entry...
# 'Tater tots' not found in 'ingredients'. Creating new entry...
# Inserted 'Tator Tot hotdish' (ID 82) with 6 ingredient rows.
# 'Butternut Squash - peeled and diced' not found in 'ingredients'. Creating new entry...
# 'Canned White Beans - drained and rinsed' not found in 'ingredients'. Creating new entry...
# '#10' not found in 'units'. Creating new entry...
# 'Frozen Cut Corn' not found in 'ingredients'. Creating new entry...
# 'bag' not found in 'units'. Creating new entry...
# 'Frozen Cut Green Beans' not found in 'ingredients'. Creating new entry...
# 'Hominy Canned - drained and rinsed' not found in 'ingredients'. Creating new entry...
# 'Roux or Corn Starch Slurry' not found in 'ingredients'. Creating new entry...
# 'enuf' not found in 'units'. Creating new entry...
# 'Russet Potato - peeled and diced' not found in 'ingredients'. Creating new entry...
# Inserted 'Three Sisters Soup' (ID 83) with 12 ingredient rows.
# 'Macadamia nut -finely ground' not found in 'ingredients'. Creating new entry...
# 'Sesame oil' not found in 'ingredients'. Creating new entry...
# 'Tilapia' not found in 'ingredients'. Creating new entry...
# Inserted 'Breaded Tilapia with macadamia' (ID 84) with 10 ingredient rows.
# 'Garlic clove' not found in 'ingredients'. Creating new entry...
# 'Sage leaves (fresh)' not found in 'ingredients'. Creating new entry...
# 'Salt ' not found in 'ingredients'. Creating new entry...
# 'Tomato Puree' not found in 'ingredients'. Creating new entry...
# 'Veggie stock' not found in 'ingredients'. Creating new entry...
# 'White wine' not found in 'ingredients'. Creating new entry...
# 'honey' not found in 'ingredients'. Creating new entry...
# Inserted 'Tomato Sage Soup' (ID 85) with 9 ingredient rows.
# 'Tuna' not found in 'ingredients'. Creating new entry...
# Inserted 'Tuna Salad' (ID 86) with 7 ingredient rows.
# Inserted 'Tuscan Bread' (ID 87) with 0 ingredient rows.
# 'Cucumber, peeled, seeded, & grated' not found in 'ingredients'. Creating new entry...
# 'Yogurt, Plain' not found in 'ingredients'. Creating new entry...
# 'Cups' not found in 'units'. Creating new entry...
# Inserted 'Tzaziki Sauce' (ID 88) with 4 ingredient rows.
# 'Canola Oil' not found in 'ingredients'. Creating new entry...
# 'Carrots -shred' not found in 'ingredients'. Creating new entry...
# 'Champagne Vinegar (or white wine vinegar)' not found in 'ingredients'. Creating new entry...
# 'Crushed red pepper - taste' not found in 'ingredients'. Creating new entry...
# 'Green onions -chop' not found in 'ingredients'. Creating new entry...
# 'Rotini Pasta' not found in 'ingredients'. Creating new entry...
# 'Shallot' not found in 'ingredients'. Creating new entry...
# 'Sliced black olives' not found in 'ingredients'. Creating new entry...
# 'Tomatoes - dice' not found in 'ingredients'. Creating new entry...
# 'green and yellow squash -rough chop' not found in 'ingredients'. Creating new entry...
# Inserted 'Summer Vegetable Pasta Salad' (ID 89) with 12 ingredient rows.
# 'celery salt' not found in 'ingredients'. Creating new entry...
# 'crushed red pepper' not found in 'ingredients'. Creating new entry...
# 'fresh chopped chives, parsley or dill ' not found in 'ingredients'. Creating new entry...
# 'lowfat cottage cheese, pureed in the robocoup' not found in 'ingredients'. Creating new entry...
# 'qt' not found in 'units'. Creating new entry...
# 'mayonaise' not found in 'ingredients'. Creating new entry...
# 'yogurt' not found in 'ingredients'. Creating new entry...
# Inserted 'Veggie Dip' (ID 90) with 9 ingredient rows.
# 'Carrots - diced' not found in 'ingredients'. Creating new entry...
# 'Leeks - halved and sliced' not found in 'ingredients'. Creating new entry...
# 'Onions - diced' not found in 'ingredients'. Creating new entry...
# 'Potato - peeled and diced' not found in 'ingredients'. Creating new entry...
# 'Venison - cubed' not found in 'ingredients'. Creating new entry...
# Inserted 'Venison Stew' (ID 91) with 12 ingredient rows.
# 'Bacon - diced' not found in 'ingredients'. Creating new entry...
# 'Carrot - diced' not found in 'ingredients'. Creating new entry...
# 'Chicken - Cooked and Cubed' not found in 'ingredients'. Creating new entry...
# 'quart' not found in 'units'. Creating new entry...
# 'Granulated Garlic' not found in 'ingredients'. Creating new entry...
# 'Ground Black Pepper' not found in 'ingredients'. Creating new entry...
# 'Ground Rosemary' not found in 'ingredients'. Creating new entry...
# 'Mushroom - sliced' not found in 'ingredients'. Creating new entry...
# 'Radish - sliced' not found in 'ingredients'. Creating new entry...
# 'Rubbed Sage' not found in 'ingredients'. Creating new entry...
# 'Thyme (dried)' not found in 'ingredients'. Creating new entry...
# 'Wild Rice - rinsed well' not found in 'ingredients'. Creating new entry...
# Inserted 'Wild Rice Hot Dish' (ID 92) with 18 ingredient rows.
# 'Balsamic  Vinegar' not found in 'ingredients'. Creating new entry...
# 'Carrot - Small Dice' not found in 'ingredients'. Creating new entry...
# 'Craisins' not found in 'ingredients'. Creating new entry...
# 'Edamame - Shelled and Cooked' not found in 'ingredients'. Creating new entry...
# 'Fresh Parsley - Chopped' not found in 'ingredients'. Creating new entry...
# 'Fresh Radish - Sliced' not found in 'ingredients'. Creating new entry...
# 'Slivered Almonds - Toasted' not found in 'ingredients'. Creating new entry...
# 'Vegetable Oil' not found in 'ingredients'. Creating new entry...
# 'White Sesame Seeds - Toasted' not found in 'ingredients'. Creating new entry...
# 'Wild Rice - Cooked' not found in 'ingredients'. Creating new entry...
# Inserted 'Wild Rice Salad' (ID 93) with 14 ingredient rows.
# 'Gallon' not found in 'units'. Creating new entry...
# Inserted 'Wild Rice Soup with Bacon' (ID 94) with 17 ingredient rows.
# 'cranberries' not found in 'ingredients'. Creating new entry...
# 'orange juice' not found in 'ingredients'. Creating new entry...
# Inserted 'cranberry sauce' (ID 95) with 3 ingredient rows.
# 'Corn' not found in 'ingredients'. Creating new entry...
# 'Heavy Cream' not found in 'ingredients'. Creating new entry...
# Inserted 'Creamed Corn' (ID 96) with 8 ingredient rows.
# 'Bread, Sliced [Thick] (Brioche is divine)' not found in 'ingredients'. Creating new entry...
# 'Cinnamon' not found in 'ingredients'. Creating new entry...
# 'Milk, Whole' not found in 'ingredients'. Creating new entry...
# 'Sugar, Granulated' not found in 'ingredients'. Creating new entry...
# 'Vanilla Extract' not found in 'ingredients'. Creating new entry...
# Inserted 'French Toast' (ID 97) with 7 ingredient rows.
# Transaction successful!
# Database connection closed.
