# %%
from pathlib import Path
import pandas as pd

def xlsx_folder_to_csv(
    src_dir,
    out_dir=None,
    sheets='all',
    delimiter=',',
    index=False,
    overwrite=False
):
    src = Path(src_dir)
    if out_dir is None:
        out = src / "csvs"
    else:
        out = Path(out_dir)
    out.mkdir(parents=True, exist_ok=True)

    files = sorted(src.glob("*.xlsx")) + sorted(src.glob("*.xls"))
    results = []

    for f in files:
        try:
            if sheets == 'all':
                xls = pd.ExcelFile(f)
                for sheet_name in xls.sheet_names:
                    df = pd.read_excel(f, sheet_name=sheet_name)
                    safe_sheet = "".join(c if c.isalnum() or c in (" ", "_", "-") else "_" for c in sheet_name).strip()
                    out_file = out / f"{f.stem}_{safe_sheet}.csv"
                    if not overwrite and out_file.exists():
                        results.append((str(f), sheet_name, 'skipped_exists', str(out_file)))
                        continue
                    df.to_csv(out_file, index=index, sep=delimiter)
                    results.append((str(f), sheet_name, 'written', str(out_file)))
            else:
                df = pd.read_excel(f, sheet_name=sheets)
                if isinstance(sheets, int):
                    out_file = out / f"{f.stem}_sheet{sheets}.csv"
                    sheet_label = f"index:{sheets}"
                else:
                    safe_sheet = "".join(c if c.isalnum() or c in (" ", "_", "-") else "_" for c in str(sheets)).strip()
                    out_file = out / f"{f.stem}_{safe_sheet}.csv"
                    sheet_label = sheets
                if not overwrite and out_file.exists():
                    results.append((str(f), sheet_label, 'skipped_exists', str(out_file)))
                    continue
                df.to_csv(out_file, index=index, sep=delimiter)
                results.append((str(f), sheet_label, 'written', str(out_file)))
        except Exception as e:
            results.append((str(f), None, 'error', str(e)))
    return results

# %%
# results = xlsx_folder_to_csv("files", out_dir="files/csvs", sheets='all', delimiter=',', index=False)
# df_results = pd.DataFrame(results, columns=["source_file", "sheet", "status", "out_path_or_error"])
# df_results
# Out:
#                              source_file                    sheet   status  \
# 0          files\Baked Mac _ Cheese.xlsx              recipe form  written
# 1               files\Baked Walleye.xlsx              recipe form  written
# 2             files\Beef Stroganoff.xlsx              recipe form  written
# 3             files\Beef Stroganoff.xlsx  additional instructions  written
# 4             files\Beef Stroganoff.xlsx      additional comments  written
# 5             files\Beef Stroganoff.xlsx               end recipe  written
# 6  files\Biscuits and Sausage Gravy.xlsx              recipe form  written
#
#                                    out_path_or_error
# 0      files\csvs\Baked Mac _ Cheese_recipe form.csv
# 1           files\csvs\Baked Walleye_recipe form.csv
# 2         files\csvs\Beef Stroganoff_recipe form.csv
# 3  files\csvs\Beef Stroganoff_additional instruct...
# 4  files\csvs\Beef Stroganoff_additional comments...
# 5          files\csvs\Beef Stroganoff_end recipe.csv
# 6  files\csvs\Biscuits and Sausage Gravy_recipe f...

# %%
results_first_sheet = xlsx_folder_to_csv("files", out_dir="files/csvs", sheets=0, delimiter=',', overwrite=False)
pd.DataFrame(results_first_sheet, columns=["source_file", "sheet", "status", "out_path_or_error"])
# Out:
#                              source_file    sheet   status  \
# 0          files\Baked Mac _ Cheese.xlsx  index:0  written
# 1               files\Baked Walleye.xlsx  index:0  written
# 2             files\Beef Stroganoff.xlsx  index:0  written
# 3  files\Biscuits and Sausage Gravy.xlsx  index:0  written
#
#                                   out_path_or_error
# 0          files\csvs\Baked Mac _ Cheese_sheet0.csv
# 1               files\csvs\Baked Walleye_sheet0.csv
# 2             files\csvs\Beef Stroganoff_sheet0.csv
# 3  files\csvs\Biscuits and Sausage Gravy_sheet0.csv
